# %%
print("Daily Expense Tracker")

#Import 
import pandas as pd
import matplotlib.pyplot as plt

print("OBJECTIVES")
print("1. Analyze daily expenses.")
print("2. Calculate total and average spending.")
print("3. Identify the highest spending category.")
print("4. Visualize spending distribution using a pie chart.")

#Load Dataset
df = pd.read_csv("expenses.csv")

print("Dataset Preview:")
print(df.head())
# Out:
# Daily Expense Tracker
# OBJECTIVES
# 1. Analyze daily expenses.
# 2. Calculate total and average spending.
# 3. Identify the highest spending category.
# 4. Visualize spending distribution using a pie chart.
# Dataset Preview:
#          Date       Category  Amount
# 0  2026-05-01           Food     120
# 1  2026-05-01      Transport      50
# 2  2026-05-02  Entertainment     200
# 3  2026-05-02       Shopping     300
# 4  2026-05-03           Food      80

# %%
#Basic Information
print("\nDataset Information:")
df.info()

print("\nSpending by Category:")
for category, amount in category_total.items():
    print(f"{category}: ${amount}")

amo = df["Amount"]

#Total Spending
total_spending = amo.sum()

print("\nTotal Spending:")
print("$", total_spending)

#Average Expenses
average_expense = amo.mean()

print("\nAverage Expense:")
print("$", round(average_expense, 2))

#highest and lowest expense
highest_expense = amo.max()
lowest_expense = amo.min()

print("\nHighest Expense: $", highest_expense)
print("Lowest Expense: $", lowest_expense)

#Spending by Category
category_total = df.groupby("Category")["Amount"].sum()

print("\nSpending by Category:")
print(category_total)

#Highest Spending Category
highest_category = category_total.idxmax()

print("\nHighest Spending Category:")
print(highest_category)

#Pie Chart Visualization
plt.figure(figsize=(7,7))

plt.pie(
    category_total,
    labels=category_total.index,
    autopct="%1.1f%%"
)

plt.title("Expense Distribution by Category")

plt.show()

#Insights
print("\nINSIGHTS")
print("Total spending was $", total_spending)
print("Average expense per transaction was $", round(average_expense, 2))
print("The highest spending category was", highest_category)
print("The lowest single expense was $", lowest_expense)
print("The highest single expense was $", highest_expense)
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      15 non-null     object
#  1   Category  15 non-null     object
#  2   Amount    15 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 492.0+ bytes
#
# Spending by Category:
# Entertainment: $500
# Food: $630
# Shopping: $700
# Transport: $150
#
# Total Spending:
# $ 1980
#
# Average Expense:
# $ 132.0
#
# Highest Expense: $ 300
# Lowest Expense: $ 40
#
# Spending by Category:
# Category
# Entertainment    500
# Food             630
# Shopping         700
# Transport        150
# Name: Amount, dtype: int64
#
# Highest Spending Category:
# Shopping
# INSIGHTS
# Total spending was $ 1980
# Average expense per transaction was $ 132.0
# The highest spending category was Shopping
# The lowest single expense was $ 40
# The highest single expense was $ 300
